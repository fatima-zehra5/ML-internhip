# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/fatima-zehra5/ML-internhip/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %% [markdown]
# **My lane:** Refresh / Content Opportunity Scoring.
#
# I chose this lane because the goal is to identify existing content that may need review or refresh. The starter data contains observed search and engagement signals such as impressions, sessions, content age, position, and trend direction. This makes it possible to rank content for review using measurable evidence rather than relying only on a fixed rule.

# %%
# This cell is for CODE (numbers, a query, a check).
print("Lane: Refresh / Content Opportunity Scoring")
print("Goal: rank existing content for refresh review using observed signals.")
# Out:
# Lane: Refresh / Content Opportunity Scoring
# Goal: rank existing content for refresh review using observed signals.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %% [markdown]
# **Research question:** Can observed search and engagement signals be used to rank existing content items for refresh review?
#
# The decision is which content items should be reviewed first. A content or SEO reviewer would act on the ranked list by inspecting high-priority items and deciding whether a refresh is appropriate. A wrong recommendation could waste review time or cause attention to be spent on content that does not need a refresh. Therefore, the output should be treated as decision-support, not as an automatic publishing decision.

# %%
print("Decision: which content items should be reviewed first?")
print("Action: use the ranked list to prioritize manual content review.")
print("Risk of wrong call: reviewer time may be spent on a low-value item.")
# Out:
# Decision: which content items should be reviewed first?
# Action: use the ranked list to prioritize manual content review.
# Risk of wrong call: reviewer time may be spent on a low-value item.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %% [markdown]
# The starter dataset is useful for the next stage because it contains a measurable set of content items with search and engagement signals.
#
# The committed starter pipeline reports **30,000 rows scored**. Of these, **16,262 rows** have the starter declining proxy label, giving a declining-label rate of **0.542 (54.2%)**.
#
# These numbers are descriptive and directional. They show that the starter data contains enough observed variation to continue investigating the refresh-review problem, but they do not prove that a refresh will cause an improvement.

# %%
# This cell is for CODE (numbers, a query, a check).
import pandas as pd
from pathlib import Path

# Look for the starter dataset in the standard repository location.
possible_paths = [
    Path("/content/ML-internhip/data/raw/content_refresh_anonymized.csv"),
    Path("data/raw/content_refresh_anonymized.csv"),
    Path("/content/data/raw/content_refresh_anonymized.csv"),
]

data_path = next((p for p in possible_paths if p.exists()), None)

if data_path is not None:
    df = pd.read_csv(data_path)

    print("Starter dataset loaded.")
    print(f"Rows: {len(df):,}")
    print(f"Columns: {len(df.columns):,}")
    print(f"Rows with impressions_90d > 0: {(df['impressions_90d'] > 0).sum():,}")
    print(f"Rows with trend_direction = down: {(df['trend_direction'].astype(str).str.lower() == 'down').sum():,}")

    display(df.head(5))
else:
    print("Starter dataset is not currently available in this Colab session.")
    print("The committed starter pipeline reports:")
    print("Rows scored: 30,000")
    print("Declining-label rows: 16,262")
    print("Declining-label rate: 0.542")
# Out:
# Starter dataset is not currently available in this Colab session.
# The committed starter pipeline reports:
# Rows scored: 30,000
# Declining-label rows: 16,262
# Declining-label rate: 0.542

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %% [markdown]
# This work can make observed and measured statements about search and engagement patterns in the available data. It can provide directional evidence and decision-support for prioritizing content review.
#
# It cannot establish that a particular change caused an improvement, and it cannot predict or explain a future search-engine algorithm change. The starter declining label is a proxy based on an observed trend, so it should not be treated as a causal outcome. Recommendations should be reviewed by a human before action.

# %%
# This cell is for CODE (numbers, a query, a check).
claims = {
    "observed": True,
    "measured": True,
    "directional": True,
    "decision_support": True,
    "causal_proof": False,
    "predicting_search_algorithm_changes": False,
}

print("Claim boundaries:")
for name, allowed in claims.items():
    print(f"{name}: {'allowed' if allowed else 'not claimed'}")
# Out:
# Claim boundaries:
# observed: allowed
# measured: allowed
# directional: allowed
# decision_support: allowed
# causal_proof: not claimed
# predicting_search_algorithm_changes: not claimed

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ yes] Every section above is filled — markdown thinking AND the code that backs it
# - [ yes] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ yes] No client names, URLs, or private queries anywhere
# - [ yes] My claims use careful words: observed, measured, directional, decision-support
# - [ yes] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
